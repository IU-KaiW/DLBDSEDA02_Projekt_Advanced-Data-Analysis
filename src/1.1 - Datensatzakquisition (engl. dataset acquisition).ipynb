# %% [markdown]
# # Datensatzprüfung (engl. dataset check)
# Anhand des [KI-Detektors](https://github.com/Kishanjaisoorya/AI-Text-Detector-python), "AI-Text-Detector-python" welcher durch einen externen Entwickler auf Basis des "nlptown/bert-base-multilingual-uncased-sentiment" Models[^1] entwickelt wurde, werden die herunterladenen Datensätze geprüft. Unter Verwendung der Bibliothek „transformers“ nutzt das Programm ein vortrainiertes Modell zur Sentimentanalyse, um eine fundierte Vermutung über die Herkunft (organisch - menschlich/synthetisch - KI) eines Textabschnitts anzustellen und zu klassifizieren.
#
#
# - Bietet einen konfigurierbaren Konfidenzschwellenwert für die Identifizierung von KI-generierten Texten.
#
# ## Anforderungen
# - Python 3.x
#
# ## Verwendung
# 1. Klonen Sie dieses Repository:
# ```bash
# https://github.com/Kishanjaisoorya/AI-Text-Detector-python.git
#
# ## Usage
#
# 1. Clone this repository:
#    ```bash
#    https://github.com/Kishanjaisoorya/AI-Text-Detector-python.git
#
# ## Run the AI text detection program
#
# python AITextDetector.py
#
#
# [^1].10.57967/hf/1515; https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment

# %% [markdown]
# # Datensatzverarbeitung (engl. dataset pipeline)

# %%
# Datensatzprüfung (engl. dataset check)
# %pip install transformers
# %pip install torch

# Datensatzsichtung (engl. dataset inspection)

# Datensatzaufbereitung (engl. dataset preparation)

# %% [markdown]
# # Datenverarbeitung (engl. data processing)

# %%
# Datenvorverarbeitung (engl. data pre-processing)
## Textvorverarbeitung (engl. text pre-processing)
## Linguistische Analyse (engl. linguistic processing)

# Datenvorbereitung (engl. data preparation)

# Datennutzung

# %% [markdown]
# # Datennachverarbeitung (engl. data post-processing)
